# %%
#testing fair coin
import numpy as np
from scipy import stats
p=0.75 #simulating an unfair coin
n=20 #number of trials
coin1= np.random.binomial(n,p)
coin1
# Out:
# 12

# %%
coin1_sd=np.sqrt()

# %%
q=1-p
q
# Out:
# 0.25

# %%
coin_std =np.sqrt(n*p*q)
coin_std
# Out:
# np.float64(1.9364916731037085)

# %% [markdown]
# ##### pvalue
# . observed mean = n*P--
# .expected

# %%
#oserved mean =n*p ---20.75
#expected mean =n*0.5 ---
z_test =(coin1-10) / (coin_std/np.sqrt(n))
z_test
# Out:
# np.float64(4.618802153517007)

# %%
pvalue =stats.norm.sf(z_test)
pvalue
# Out:
# np.float64(1.9298082184642186e-06)
