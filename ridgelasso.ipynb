# %%
# Run this cell without changes
#importoing the data 
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('house_prices_dataset.csv', index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 3 to 1
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bathrooms       1000 non-null   int64
#  1   sqft_living     1000 non-null   int64
#  2   sqft_lot        1000 non-null   int64
#  3   floors          1000 non-null   int64
#  4   waterfront      1000 non-null   int64
#  5   view            1000 non-null   int64
#  6   condition       1000 non-null   int64
#  7   grade           1000 non-null   int64
#  8   year_built      1000 non-null   int64
#  9   year_renovated  1000 non-null   int64
#  10  zipcode         1000 non-null   int64
#  11  lat             1000 non-null   float64
#  12  long            1000 non-null   float64
#  13  price           1000 non-null   float64
# dtypes: float64(3), int64(11)
# memory usage: 117.2 KB

# %%
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# Create X and y
y = df['price']
X = df.drop(columns=['price'])

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)

# Separate X data into continuous vs. categorical
X_train_cont = X_train.select_dtypes(include='number')
X_test_cont = X_test.select_dtypes(include='number')
X_train_cat = X_train.select_dtypes(exclude='number')
X_test_cat = X_test.select_dtypes(exclude='number')

# Impute missing values for continuous columns
impute_cont = SimpleImputer(strategy='median')
X_train_cont = impute_cont.fit_transform(X_train_cont)
X_test_cont = impute_cont.transform(X_test_cont)

# Scale continuous columns
scaler = MinMaxScaler()
X_train_cont = scaler.fit_transform(X_train_cont)
X_test_cont = scaler.transform(X_test_cont)

# Only process categorical columns if they exist
if X_train_cat.shape[1] > 0:
    # Impute missing values for categorical columns
    impute_cat = SimpleImputer(strategy='constant', fill_value='missing')
    X_train_cat = impute_cat.fit_transform(X_train_cat)
    X_test_cat = impute_cat.transform(X_test_cat)
    
    # One-hot encode categorical columns
    ohe = OneHotEncoder(handle_unknown='ignore')
    X_train_cat = ohe.fit_transform(X_train_cat)
    X_test_cat = ohe.transform(X_test_cat)
    
    # Combine continuous and categorical features
    X_train_preprocessed = np.concatenate([X_train_cont, X_train_cat.todense()], axis=1)
    X_test_preprocessed = np.concatenate([X_test_cont, X_test_cat.todense()], axis=1)
else:
    # If no categorical columns, just use continuous features
    X_train_preprocessed = X_train_cont
    X_test_preprocessed = X_test_cont

print("Preprocessing complete.")
print("X_train shape:", X_train_preprocessed.shape)
print("X_test shape:", X_test_preprocessed.shape)
# Out:
# Preprocessing complete.
# X_train shape: (750, 13)
# X_test shape: (250, 13)

# %%
# Replace None with appropriate code
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# Fit the model
linreg = None

# Print R2 and MSE for training and test sets
None

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Initialize and fit the Linear Regression model
linreg = LinearRegression()
linreg.fit(X_train_preprocessed, y_train)

# Predict on training and test sets
y_train_pred = linreg.predict(X_train_preprocessed)
y_test_pred = linreg.predict(X_test_preprocessed)

# Calculate R-squared
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

# Calculate Mean Squared Error
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)

# Print results
print(f"Training R²: {r2_train:.4f}, Training MSE: {mse_train:.4f}")
print(f"Test R²: {r2_test:.4f}, Test MSE: {mse_test:.4f}")
# Out:
# Training R²: 0.9925, Training MSE: 803566238.5181
# Test R²: 0.9902, Test MSE: 1026291597.9469

# %%
from sklearn.linear_model import Ridge, Lasso
scores=[]
for model in [Ridge(alpha=1.0), Lasso(alpha=0.1)]:
  ridge=model
  ridge.fit(X_train_preprocessed, y_train)
  y_train_pred = ridge.predict(X_train_preprocessed)
  y_test_pred = ridge.predict(X_test_preprocessed)
  r2_train = r2_score(y_train, y_train_pred)
  r2_test = r2_score(y_test, y_test_pred)
  scores.append((model.__class__.__name__, r2_train, r2_test))
  print(f"{model.__class__.__name__} - Training R²: {r2_train:.4f}, Test R²: {r2_test:.4f}")
# Initialize and fit the Linear Regression model
linreg = LinearRegression()
linreg.fit(X_train_preprocessed, y_train)
# Predict on training and test sets
y_train_pred = linreg.predict(X_train_preprocessed) 
y_test_pred = linreg.predict(X_test_preprocessed)
# Calculate R-squared
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)
# Calculate Mean Squared Error
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred) 
#print results
print(f"Training R²: {r2_train:.4f}, Training MSE: {mse_train:.4f}")
print(f"Test R²: {r2_test:.4f}, Test MSE: {mse_test:.4f}")
# Initialize and fit the Linear Regression model
linreg = LinearRegression()
linreg.fit(X_train_preprocessed, y_train)
# Predict on training and test sets
y_train_pred = linreg.predict(X_train_preprocessed)
y_test_pred = linreg.predict(X_test_preprocessed)
# Calculate R-squared
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)
# Calculate Mean Squared Error
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
# Print results
print(f"Training R²: {r2_train:.4f}, Training MSE: {mse_train:.4f}")
print(f"Test R²: {r2_test:.4f}, Test MSE: {mse_test:.4f}")
# Initialize and fit the Linear Regression model
linreg = LinearRegression()
linreg.fit(X_train_preprocessed, y_train)
# Predict on training and test sets
y_train_pred = linreg.predict(X_train_preprocessed)
y_test_pred = linreg.predict(X_test_preprocessed)
# Calculate R-squared
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)
# Calculate Mean Squared Error
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
# Print results
print(f"Training R²: {r2_train:.4f}, Training MSE: {mse_train:.4f}")
print(f"Test R²: {r2_test:.4f}, Test MSE: {mse_test:.4f}")
# Initialize and fit the Linear Regression model
linreg = LinearRegression()
linreg.fit(X_train_preprocessed, y_train)
# Predict on training and test sets
y_train_pred = linreg.predict(X_train_preprocessed)
y_test_pred = linreg.predict(X_test_preprocessed)
# Calculate R-squared
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)
# Calculate Mean Squared Error
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
# Print results
print(f"Training R²: {r2_train:.4f}, Training MSE: {mse_train:.4f}")
print(f"Test R²: {r2_test:.4f}, Test MSE: {mse_test:.4f}")
# Initialize and fit the Linear Regression model
linreg = LinearRegression()
linreg.fit(X_train_preprocessed, y_train)
# Predict on training and test sets
y_train_pred = linreg.predict(X_train_preprocessed)
y_test_pred = linreg.predict(X_test_preprocessed)
# Calculate R-squared
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)
# Calculate Mean Squared Error
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
# Print results
print(f"Training R²: {r2_train:.4f}, Training MSE: {mse_train:.4f}")
print(f"Test R²: {r2_test:.4f}, Test MSE: {mse_test:.4f}")
# Initialize and fit the Linear Regression model
linreg = LinearRegression()
linreg.fit(X_train_preprocessed, y_train)
# Predict on training and test sets
y_train_pred = linreg.predict(X_train_preprocessed)
y_test_pred = linreg.predict(X_test_preprocessed)
# Calculate R-squared
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred) 
# Calculate Mean Squared Error
mse_train = mean_squared_error(y_train, y_train_pred) 
mse_test = mean_squared_error(y_test, y_test_pred)
# Print results
print(f"Training R²: {r2_train:.4f}, Training MSE: {mse_train:.4f}")
print(f"Test R²: {r2_test:.4f}, Test MSE: {mse_test:.4f}")
# Out:
# Ridge - Training R²: 0.9923, Test R²: 0.9901
# Lasso - Training R²: 0.9925, Test R²: 0.9902
# Training R²: 0.9925, Training MSE: 803566238.5181
# Test R²: 0.9902, Test MSE: 1026291597.9469
# Training R²: 0.9925, Training MSE: 803566238.5181
# Test R²: 0.9902, Test MSE: 1026291597.9469
# Training R²: 0.9925, Training MSE: 803566238.5181
# Test R²: 0.9902, Test MSE: 1026291597.9469
# Training R²: 0.9925, Training MSE: 803566238.5181
# Test R²: 0.9902, Test MSE: 1026291597.9469
# Training R²: 0.9925, Training MSE: 803566238.5181
# Test R²: 0.9902, Test MSE: 1026291597.9469
# Training R²: 0.9925, Training MSE: 803566238.5181
# Test R²: 0.9902, Test MSE: 1026291597.9469
