# %%
#how many seconds are there in 42 minutes 42 seconds?
minutes=42
seconds=42
total_seconds=minutes*60+seconds
print(f"total_seconds=",total_seconds)
# Out:
# total_seconds= 2562

# %%
#how many miles are there in 10 kilometers?
kilometres=10
miles =kilometres *0.621371
print (f"miles=",{miles})
# Out:
# miles= {6.21371}

# %%
#if you run a 10 kilometer race in 42 minutes 42 seconds, what is your average pace (time per mile in minutes and seconds)?what is your average speed in miles per hour?

# %%
#the volume a sphere with radius is 4/3 pi r^3. what is the vollume of a sphere with radius 5?
import math as m
r=5
v=4/3*m.pi *r**3
print(f"volume",v)
# Out:
# volume 523.5987755982989

# %%
#if i leave my house at 6:52 am and run 10 mile at an easy pace (8:15 per mile )then 3 miles at tempo(7:12 per mile) and 1 mile at easy pace again, what time do i get home for breakfst?
easy_pace=8*60+15
tempo_pace=7*60+12
total_time=10*easy_pace+3*tempo_pace+1*easy_pace
total_time_in_hours=total_time/3600
print(f"total_time_in_hours=",total_time_in_hours)
# Out:
# total_time_in_hours= 1.8725
